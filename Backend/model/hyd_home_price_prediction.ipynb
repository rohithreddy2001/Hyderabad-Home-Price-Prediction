# %% [markdown]
# <h1 style='color:#007fd4' align='center'>Data Science Regression Project: Predicting Home Prices in Hyderabad</h1>

# %% [markdown]
# Dataset is downloaded from here: https://www.kaggle.com/datasets/chilledwanker/makaan-house-prices-dataset

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib 
matplotlib.rcParams["figure.figsize"] = (20,10)

# %% [markdown]
# <h2 style='color:#007fd4' align='left'>Loading Hyd House prices data into a dataframe</h2>

# %%
df1 = pd.read_csv("Hyd_House_Prices.csv")
df1.head(10)
# Out:
#    Unnamed: 0                            Builder Name       City  \
# 0           0  Theme Ambience InfrastructuresBUILDER0  Hyderabad
# 1           1                Elemental RealtyBUILDER0  Hyderabad
# 2           2     R V Nirmaan Private LimitedBUILDER0  Hyderabad
# 3           3                Risinia BuildersBUILDER0  Hyderabad
# 4           4               Cyber City OrianaBUILDER0  Hyderabad
# 5           5         Shree Vasavi DevelopersBUILDER0  Hyderabad
# 6           6              Jain ConstructionsBUILDER0  Hyderabad
# 7           7                     Ira RealityBUILDER0  Hyderabad
# 8           8               Hallmark BuildersBUILDER0  Hyderabad
# 9           9                       APR GroupBUILDER0  Hyderabad
#
#                     Locality     Property Type  Price in Crores  Area in Sqft  \
# 0                    Attapur  3 BHK Apartment            1.5000          2090
# 1                 Patancheru      4 BHK Villa            1.4800          1930
# 2                    Miyapur  3 BHK Apartment            1.2700          1967
# 3  Pragathi Nagar Kukatpally  2 BHK Apartment            0.7345          1312
# 4                 Kukatpally  3 BHK Apartment            1.2800          1480
# 5                    Attapur  3 BHK Apartment            1.4600          2005
# 6                 Malkajgiri  3 BHK Apartment            1.6300          2245
# 7                   Adibatla      4 BHK Villa            3.1400          3705
# 8                Patighanpur  3 BHK Apartment            1.1300          1885
# 9                 Bachupally      4 BHK Villa            4.0800          3400
#
#   Construction Status         Age of property
# 0  Under Construction  Possession by Dec 2024
# 1  Under Construction  Possession by Nov 2024
# 2  Under Construction  Possession by Nov 2024
# 3  Under Construction  Possession by May 2025
# 4  Under Construction  Possession by Nov 2025
# 5  Under Construction  Possession by Nov 2024
# 6  Under Construction  Possession by Nov 2023
# 7  Under Construction  Possession by Dec 2025
# 8  Under Construction  Possession by Nov 2025
# 9  Under Construction  Possession by Nov 2024

# %%
# from df1 drop unnamed column
df1 = df1.drop(['Unnamed: 0'], axis=1)
df1.head(10)
# Out:
#                              Builder Name       City  \
# 0  Theme Ambience InfrastructuresBUILDER0  Hyderabad
# 1                Elemental RealtyBUILDER0  Hyderabad
# 2     R V Nirmaan Private LimitedBUILDER0  Hyderabad
# 3                Risinia BuildersBUILDER0  Hyderabad
# 4               Cyber City OrianaBUILDER0  Hyderabad
# 5         Shree Vasavi DevelopersBUILDER0  Hyderabad
# 6              Jain ConstructionsBUILDER0  Hyderabad
# 7                     Ira RealityBUILDER0  Hyderabad
# 8               Hallmark BuildersBUILDER0  Hyderabad
# 9                       APR GroupBUILDER0  Hyderabad
#
#                     Locality     Property Type  Price in Crores  Area in Sqft  \
# 0                    Attapur  3 BHK Apartment            1.5000          2090
# 1                 Patancheru      4 BHK Villa            1.4800          1930
# 2                    Miyapur  3 BHK Apartment            1.2700          1967
# 3  Pragathi Nagar Kukatpally  2 BHK Apartment            0.7345          1312
# 4                 Kukatpally  3 BHK Apartment            1.2800          1480
# 5                    Attapur  3 BHK Apartment            1.4600          2005
# 6                 Malkajgiri  3 BHK Apartment            1.6300          2245
# 7                   Adibatla      4 BHK Villa            3.1400          3705
# 8                Patighanpur  3 BHK Apartment            1.1300          1885
# 9                 Bachupally      4 BHK Villa            4.0800          3400
#
#   Construction Status         Age of property
# 0  Under Construction  Possession by Dec 2024
# 1  Under Construction  Possession by Nov 2024
# 2  Under Construction  Possession by Nov 2024
# 3  Under Construction  Possession by May 2025
# 4  Under Construction  Possession by Nov 2025
# 5  Under Construction  Possession by Nov 2024
# 6  Under Construction  Possession by Nov 2023
# 7  Under Construction  Possession by Dec 2025
# 8  Under Construction  Possession by Nov 2025
# 9  Under Construction  Possession by Nov 2024

# %%
df1.shape
# Out:
# (5960, 8)

# %% [markdown]
# <h2 style='color:#007fd4' align='left'>Renaming column names for better readability</h2>

# %%
df1.rename(columns={
    'Builder Name': 'builder_name',
    'City': 'city',
    'Locality': 'locality',
    'Property Type': 'property_type',
    'Price in Crores': 'price_in_crores',
    'Area in Sqft': 'area_in_sqft',
    'Construction Status': 'construction_status',
    'Age of property': 'age_of_property',
}, inplace=True)

# %% [markdown]
# <h2 style='color:#007fd4' align='left'>Data Cleaning</h2>

# %%
df1.isnull().sum()
# Out:
# builder_name             0
# city                     0
# locality                 0
# property_type            0
# price_in_crores          0
# area_in_sqft             0
# construction_status      0
# age_of_property        174
# dtype: int64

# %%
df1.locality.value_counts()
# Out:
# locality
# Miyapur             205
# Kollur              202
# Yacharam            164
# Narsingi            149
# Kokapet             137
#                    ...
# Erragadda             1
# Narepally             1
# Rameswaram Banda      1
# Masab Tank            1
# Devatabowli           1
# Name: count, Length: 299, dtype: int64

# %%
nulls = df1[df1.age_of_property.isnull()]
nulls.head(29)
# Out:
#                        builder_name       city                locality  \
# 53   Alekya Infraa DevelopersAGENT0  Hyderabad                   Aroor
# 67             sellerVERIFIED OWNER  Hyderabad               Shadnagar
# 76             sellerVERIFIED OWNER  Hyderabad                 Kadthal
# 128  Alekya Infraa DevelopersAGENT0  Hyderabad  Nallagandla Gachibowli
# 129  Alekya Infraa DevelopersAGENT0  Hyderabad                   Aroor
# 353            sellerVERIFIED OWNER  Hyderabad              Shamshabad
# 360  Alekya Infraa DevelopersAGENT0  Hyderabad             Sadashivpet
# 361  Alekya Infraa DevelopersAGENT0  Hyderabad             Sadashivpet
# 362  Alekya Infraa DevelopersAGENT0  Hyderabad             Sadashivpet
# 374  Alekya Infraa DevelopersAGENT0  Hyderabad             Sadashivpet
# 873            sellerVERIFIED OWNER  Hyderabad                 Medchal
# 874            sellerVERIFIED OWNER  Hyderabad              Auto Nagar
# 895            sellerVERIFIED OWNER  Hyderabad             Sadashivpet
# 896            sellerVERIFIED OWNER  Hyderabad             Bhuvanagiri
# 899            sellerVERIFIED OWNER  Hyderabad               Alampally
# 902            sellerVERIFIED OWNER  Hyderabad             Taramatipet
# 908            sellerVERIFIED OWNER  Hyderabad               Jadcherla
# 909            sellerVERIFIED OWNER  Hyderabad               Shadnagar
# 910            sellerVERIFIED OWNER  Hyderabad                Kondakal
# 917            sellerVERIFIED OWNER  Hyderabad               Shadnagar
# 919            sellerVERIFIED OWNER  Hyderabad               Shadnagar
# 922            sellerVERIFIED OWNER  Hyderabad               Shadnagar
# 923            sellerVERIFIED OWNER  Hyderabad               Shadnagar
# 926            sellerVERIFIED OWNER  Hyderabad                Dundigal
# 928            sellerVERIFIED OWNER  Hyderabad              Turkapally
# 931            sellerVERIFIED OWNER  Hyderabad             Taramatipet
# 934            sellerVERIFIED OWNER  Hyderabad                Kandukur
# 935            sellerVERIFIED OWNER  Hyderabad                Kandukur
# 937            sellerVERIFIED OWNER  Hyderabad             Sadashivpet
#
#                               property_type  price_in_crores  area_in_sqft  \
# 53                        Residential Plot            0.2960          1665
# 67     Residential PlotShadnagar, Hyderabad           0.4000          2250
# 76       Residential PlotKadthal, Hyderabad           0.2500         12150
# 128                       Residential Plot            0.2720          1530
# 129                       Residential Plot            0.4000          2250
# 353   Residential PlotShamshabad, Hyderabad           0.2562          1650
# 360                       Residential Plot            0.2340          1620
# 361                       Residential Plot            0.2210          1530
# 362                       Residential Plot            0.2119          1467
# 374                       Residential Plot            0.4875          3375
# 873      Residential PlotMedchal, Hyderabad           0.4170          1500
# 874   Residential PlotAuto Nagar, Hyderabad           2.2000          3600
# 895  Residential PlotSadashivpet, Hyderabad           0.0730          1323
# 896  Residential PlotBhuvanagiri, Hyderabad           0.2839          1503
# 899    Residential PlotAlampally, Hyderabad           0.1200          1647
# 902  Residential PlotTaramatipet, Hyderabad           0.3100          1500
# 908    Residential PlotJadcherla, Hyderabad           0.2670          1201
# 909    Residential PlotShadnagar, Hyderabad           0.2400          1350
# 910                       Residential Plot            0.6600          2244
# 917    Residential PlotShadnagar, Hyderabad           0.3200          1800
# 919    Residential PlotShadnagar, Hyderabad           0.5562          2781
# 922    Residential PlotShadnagar, Hyderabad           0.1700          1125
# 923                       Residential Plot            0.2850          1503
# 926                       Residential Plot            0.6600          1800
# 928   Residential PlotTurkapally, Hyderabad           0.4600          2196
# 931  Residential PlotTaramatipet, Hyderabad           0.3958          1827
# 934     Residential PlotKandukur, Hyderabad           0.1000          1350
# 935     Residential PlotKandukur, Hyderabad           0.0907          1350
# 937  Residential PlotSadashivpet, Hyderabad           0.4400          3600
#
#     construction_status age_of_property
# 53                  New             NaN
# 67               Resale             NaN
# 76               Resale             NaN
# 128                 New             NaN
# 129                 New             NaN
# 353                 New             NaN
# 360                 New             NaN
# 361                 New             NaN
# 362                 New             NaN
# 374                 New             NaN
# 873              Resale             NaN
# 874              Resale             NaN
# 895              Resale             NaN
# 896              Resale             NaN
# 899              Resale             NaN
# 902              Resale             NaN
# 908              Resale             NaN
# 909              Resale             NaN
# 910              Resale             NaN
# 917              Resale             NaN
# 919              Resale             NaN
# 922              Resale             NaN
# 923              Resale             NaN
# 926              Resale             NaN
# 928              Resale             NaN
# 931              Resale             NaN
# 934              Resale             NaN
# 935              Resale             NaN
# 937              Resale             NaN

# %%
# filter rows where Property Type contains 'Residential Plot'
df_residential_plots = df1[df1.property_type.str.contains('Residential Plot', case=False, na=False)]
df_residential_plots.shape, df_residential_plots.head()
# Out:
# ((1857, 8),
#                        builder_name       city     locality      property_type  \
#  12           Beyond NatureBUILDER0  Hyderabad  Sadashivpet  Residential Plot
#  27        G square HousingBUILDER0  Hyderabad   Choutuppal  Residential Plot
#  40           Beyond NatureBUILDER0  Hyderabad  Sadashivpet  Residential Plot
#  50        G square HousingBUILDER0  Hyderabad   Choutuppal  Residential Plot
#  53  Alekya Infraa DevelopersAGENT0  Hyderabad        Aroor  Residential Plot
#
#      price_in_crores  area_in_sqft construction_status         age_of_property
#  12           0.6300          3150                 New  Possession by Feb 2024
#  27           0.9781          4797                 New  Possession by Apr 2024
#  40           0.3600          1800                 New  Possession by Feb 2024
#  50           0.4899          2403                 New  Possession by Apr 2024
#  53           0.2960          1665                 New                     NaN  )

# %%
df2 = df1[~df1.property_type.str.contains('Residential Plot', case=False, na=False)]
df2.shape
# Out:
# (4103, 8)

# %% [markdown]
# <h2 style='color:#007fd4' align='left'>Feature Engineering: Creating new columns for property type & bedrooms</h2>

# %%
df2['bedrooms'] = df2['property_type'].str.extract(r'(\d+)\s*BHK', expand=False).astype(float)
df2
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_6888\2867917931.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['bedrooms'] = df2['property_type'].str.extract(r'(\d+)\s*BHK', expand=False).astype(float)
#                                 builder_name       city  \
# 0     Theme Ambience InfrastructuresBUILDER0  Hyderabad
# 1                   Elemental RealtyBUILDER0  Hyderabad
# 2        R V Nirmaan Private LimitedBUILDER0  Hyderabad
# 3                   Risinia BuildersBUILDER0  Hyderabad
# 4                  Cyber City OrianaBUILDER0  Hyderabad
# ...                                      ...        ...
# 5955                    TSR PROPERTIESAGENT0  Hyderabad
# 5956                    TSR PROPERTIESAGENT0  Hyderabad
# 5957                    TSR PROPERTIESAGENT0  Hyderabad
# 5958                    TSR PROPERTIESAGENT0  Hyderabad
# 5959                    TSR PROPERTIESAGENT0  Hyderabad
#
#                        locality        property_type  price_in_crores  \
# 0                       Attapur     3 BHK Apartment            1.5000
# 1                    Patancheru         4 BHK Villa            1.4800
# 2                       Miyapur     3 BHK Apartment            1.2700
# 3     Pragathi Nagar Kukatpally     2 BHK Apartment            0.7345
# 4                    Kukatpally     3 BHK Apartment            1.2800
# ...                         ...                  ...              ...
# 5955               Nanakramguda     2 BHK Apartment            0.9073
# 5956               Nanakramguda     3 BHK Apartment            1.5300
# 5957               Nanakramguda     2 BHK Apartment            0.9073
# 5958                   Narsingi  2 BHK ApartmentNars           0.6893
# 5959                   Narsingi  2 BHK ApartmentNars           0.6801
#
#       area_in_sqft construction_status         age_of_property  bedrooms
# 0             2090  Under Construction  Possession by Dec 2024       3.0
# 1             1930  Under Construction  Possession by Nov 2024       4.0
# 2             1967  Under Construction  Possession by Nov 2024       3.0
# 3             1312  Under Construction  Possession by May 2025       2.0
# 4             1480  Under Construction  Possession by Nov 2025       3.0
# ...            ...                 ...                     ...       ...
# 5955          1315  Under Construction  Possession by Nov 2026       2.0
# 5956          2230  Under Construction  Possession by Nov 2026       3.0
# 5957          1315  Under Construction  Possession by Nov 2026       2.0
# 5958          1130  Under Construction             2 Bathrooms       2.0
# 5959          1115  Under Construction             2 Bathrooms       2.0
#
# [4103 rows x 9 columns]

# %%
df2 = df2.dropna(subset=['bedrooms'])
df2.shape
# Out:
# (4099, 9)

# %%
df2.property_type.unique()
# Out:
# array(['3 BHK Apartment ', '4 BHK Villa ', '2 BHK Apartment ',
#        '4 BHK Apartment ', '4 BHK Independent House ', '1 BHK Apartment ',
#        '3 BHK Independent House ',
#        '2 BHK ApartmentPragathi Nagar Kukatpally, Hyderabad',
#        '3 BHK Independent FloorMalakpet, Hyderabad',
#        '3 BHK ApartmentKollur, Hyderabad',
#        '3 BHK ApartmentKokapet, Hyderabad',
#        '3 BHK ApartmentAlwal, Hyderabad',
#        '4 BHK VillaPatancheru, Hyderabad',
#        '4 BHK VillaManneguda, Hyderabad',
#        '2 BHK VillaNandigama, Hyderabad',
#        '3 BHK VillaIDA Pashamylaram, Hyderabad', '4 BHK ApartmentNars',
#        '3 BHK ApartmentSa', '2 BHK Independent HouseLaxmiguda, Hyderabad',
#        '2 BHK ApartmentToli Chowki, Hyderabad', '5 BHK Apartment ',
#        '2 BHK ApartmentBowrampet, Hyderabad',
#        '3 BHK VillaKompally, Hyderabad',
#        '2 BHK ApartmentBachupally, Hyderabad',
#        '3 BHK VillaBowrampet, Hyderabad',
#        '2 BHK ApartmentMiyapur, Hyderabad',
#        '3 BHK ApartmentKukatpally, Hyderabad',
#        '2 BHK ApartmentKukatpally, Hyderabad',
#        '2 BHK ApartmentNizampet, Hyderabad',
#        '3 BHK ApartmentPragathi Nagar Kukatpally, Hyderabad',
#        '3 BHK Villa ', '2 BHK ApartmentKollur, Hyderabad',
#        '2 BHK VillaKollur, Hyderabad', '2 BHK VillaRudraram, Hyderabad',
#        '2 BHK ApartmentBandlaguda Jagir, Hyderabad', '2 BHK ApartmentAm',
#        '3 BHK ApartmentBairagiguda, Hyderabad',
#        '10 BHK Independent HouseLB Nagar, Hyderabad',
#        '2 BHK ApartmentIsnapur, Hyderabad',
#        '3 BHK ApartmentHyder Nagar, Hyderabad',
#        '3 BHK Independent HouseAlwal, Hyderabad', '5 BHK Villa ',
#        '3 BHK Independent HouseHayathnagar, Hyderabad',
#        '2 BHK Independent HouseBoduppal, Hyderabad',
#        '5 BHK Independent HouseMunganoor, Hyderabad',
#        '8 BHK Independent HouseSanjeeva Reddy Nagar, Hyderabad',
#        '4 BHK Independent HouseKrishna Reddy Pet, Hyderabad',
#        '3 BHK ApartmentGowlidody, Hyderabad', '5 BHK VillaSeril',
#        '2 BHK ApartmentDammaiguda, Hyderabad',
#        '4 BHK Independent FloorDammaiguda, Hyderabad',
#        '3 BHK ApartmentUppal, Hyderabad',
#        '3 BHK VillaIbrahimpatnam, Hyderabad',
#        '2 BHK ApartmentRampally, Hyderabad',
#        '3 BHK ApartmentGandi Maisamma, Hyderabad',
#        '2 BHK Independent HouseKrishna Reddy Pet, Hyderabad',
#        '2 BHK Independent House ', '3 BHK ApartmentNizampet, Hyderabad',
#        '4 BHK VillaYapral, Hyderabad', '2 BHK ApartmentNars',
#        '2 BHK ApartmentMadhapur, Hyderabad', '8 BHK Independent HouseAm',
#        '3 BHK ApartmentNagaram, Hyderabad',
#        '2 BHK ApartmentNawab Saheb Kunta, Hyderabad',
#        '4 BHK Independent HouseUppal, Hyderabad',
#        '3 BHK VillaBhanur, Hyderabad',
#        '2 BHK ApartmentManneguda, Hyderabad',
#        '3 BHK ApartmentYapral, Hyderabad',
#        '2 BHK ApartmentBadangpet, Hyderabad',
#        '5 BHK Independent HouseYapral, Hyderabad',
#        '7 BHK Independent HouseShamshabad, Hyderabad',
#        '4 BHK VillaRamoji Film city, Hyderabad',
#        '2 BHK Independent HouseBadangpet, Hyderabad',
#        '3 BHK Independent HouseHyderguda, Hyderabad',
#        '3 BHK ApartmentChandanagar, Hyderabad',
#        '3 BHK Independent FloorKukatpally, Hyderabad',
#        '3 BHK VillaHanamkonda, Hyderabad',
#        '2 BHK Independent HouseIsnapur, Hyderabad',
#        '3 BHK VillaBasuragadi Village, Hyderabad',
#        '2 BHK ApartmentPuppalaguda, Hyderabad',
#        '3 BHK ApartmentMallapur, Hyderabad',
#        '3 BHK VillaSathamrai Village, Hyderabad',
#        '6 BHK Independent HouseMehdipatnam, Hyderabad',
#        '2 BHK ApartmentHappy Homes Colony, Hyderabad',
#        '10 BHK Independent HouseNallakunta, Hyderabad',
#        '3 BHK ApartmentKapra, Hyderabad',
#        '3 BHK VillaBongloor, Hyderabad',
#        '3 BHK ApartmentKhairatabad Road, Hyderabad',
#        '3 BHK ApartmentBanjara Hills, Hyderabad',
#        '2 BHK Independent Housemuthangi, Hyderabad',
#        '3 BHK Independent HouseAdibatla, Hyderabad',
#        '2 BHK ApartmentGajularamaram, Hyderabad',
#        '2 BHK ApartmentChandanagar, Hyderabad',
#        '2 BHK ApartmentMalkajgiri, Hyderabad',
#        '2 BHK Independent HouseTurkaYamjal, Hyderabad',
#        '3 BHK Independent HouseAdikmet, Hyderabad',
#        '4 BHK VillaVelimela, Hyderabad',
#        '3 BHK Independent FloorHafeezpet, Hyderabad',
#        '4 BHK Independent HouseKapra, Hyderabad', '3 BHK ApartmentSeril',
#        '2 BHK ApartmentMallapur, Hyderabad',
#        '3 BHK Independent HouseSeril',
#        '3 BHK Independent HouseQutub Shahi Tombs, Hyderabad',
#        '2 BHK ApartmentMedchal, Hyderabad',
#        '4 BHK VillaTukkuguda, Hyderabad', '4 BHK VillaMokila, Hyderabad',
#        '3 BHK ApartmentSuraram, Hyderabad',
#        '6 BHK Independent HouseKushaiguda, Hyderabad',
#        '4 BHK Independent HouseBowenpally, Hyderabad',
#        '6 BHK Independent HouseAlwal, Hyderabad',
#        '10 BHK VillaRamachandra Puram, Hyderabad', '10 BHK VillaAm',
#        '2 BHK ApartmentAlwal, Hyderabad',
#        '3 BHK ApartmentMadhapur, Hyderabad',
#        '7 BHK Independent HouseOld Malakpet, Hyderabad',
#        '8 BHK Independent HouseKothapet, Hyderabad',
#        '6 BHK VillaKapra, Hyderabad',
#        '3 BHK ApartmentHayathnagar, Hyderabad',
#        '2 BHK ApartmentPocharam, Hyderabad',
#        '2 BHK ApartmentTukkuguda, Hyderabad',
#        '4 BHK VillaBachupally, Hyderabad',
#        '3 BHK Independent HouseGajularamaram, Hyderabad',
#        '3 BHK ApartmentPocharam, Hyderabad',
#        '4 BHK Independent HouseAlmasguda, Hyderabad',
#        '2 BHK ApartmentLB Nagar, Hyderabad',
#        '2 BHK ApartmentBoduppal, Hyderabad',
#        '3 BHK ApartmentManikonda, Hyderabad',
#        '2 BHK ApartmentKushaiguda, Hyderabad',
#        '2 BHK Independent HouseJai Suryapatnam, Hyderabad',
#        '2 BHK Independent HouseMoula Ali, Hyderabad',
#        '3 BHK ApartmentJubilee Hills, Hyderabad',
#        '2 BHK ApartmentKapra, Hyderabad', '5 BHK VillaSa',
#        '3 BHK ApartmentBachupally, Hyderabad',
#        '3 BHK ApartmentBegumpet, Hyderabad',
#        '5 BHK Independent HouseMedchal, Hyderabad',
#        '3 BHK ApartmentQutub Shahi Tombs, Hyderabad',
#        '3 BHK Apartmentchandrayangutta, Hyderabad',
#        '2 BHK ApartmentVanasthalipuram, Hyderabad',
#        '3 BHK VillaPatancheru, Hyderabad',
#        '3 BHK Independent HouseKarwan, Hyderabad',
#        '2 BHK ApartmentPatancheru, Hyderabad',
#        '2 BHK Independent FloorMoula Ali, Hyderabad',
#        '2 BHK Independent HouseBorabanda, Hyderabad',
#        '4 BHK ApartmentKokapet, Hyderabad',
#        '4 BHK ApartmentAttapur, Hyderabad',
#        '5 BHK Independent HouseAlwal, Hyderabad',
#        '5 BHK Independent HouseBolarum, Hyderabad',
#        '3 BHK Independent HouseDammaiguda, Hyderabad',
#        '10 BHK Independent HouseVanasthalipuram, Hyderabad',
#        '2 BHK ApartmentHafeezpet, Hyderabad',
#        '6 BHK Independent HouseSaidabad, Hyderabad',
#        '2 BHK ApartmentErragadda, Hyderabad',
#        '4 BHK Independent HouseTarnaka, Hyderabad',
#        '2 BHK ApartmentMasab Tank, Hyderabad',
#        '4 BHK ApartmentUpparpally, Hyderabad',
#        '2 BHK ApartmentGundlapochampalli, Hyderabad',
#        '3 BHK ApartmentUpparpally, Hyderabad',
#        '2 BHK ApartmentSuraram, Hyderabad', '4 BHK VillaKapra, Hyderabad',
#        '7 BHK Independent HouseNagaram, Hyderabad',
#        '3 BHK ApartmentNawab Saheb Kunta, Hyderabad',
#        '2 BHK ApartmentRamachandra Puram, Hyderabad',
#        '3 BHK ApartmentKondapur, Hyderabad',
#        '3 BHK ApartmentIbrahim Bagh, Hyderabad',
#        '2 BHK ApartmentB N reddy nagar, Hyderabad',
#        '10 BHK Independent HouseHyder Nagar, Hyderabad',
#        '2 BHK Independent HouseBalapur, Hyderabad',
#        '5 BHK Independent HouseMoti Nagar, Hyderabad',
#        '2 BHK VillaIndresham, Hyderabad',
#        '9 BHK Independent HouseSaidabad, Hyderabad',
#        '3 BHK VillaPasumamula, Hyderabad', '8 BHK Villa ',
#        '2 BHK ApartmentVelimela, Hyderabad',
#        '2 BHK ApartmentMallampet, Hyderabad',
#        '2 BHK Independent HouseKadthal, Hyderabad',
#        '5 BHK Independent HouseUppal, Hyderabad',
#        '3 BHK ApartmentMiyapur, Hyderabad',
#        '2 BHK ApartmentAmberpet, Hyderabad',
#        '2 BHK ApartmentNallakunta, Hyderabad',
#        '2 BHK Independent HouseMunganoor, Hyderabad',
#        '3 BHK Independent HouseNallakunta, Hyderabad', '2 BHK Villa ',
#        '5 BHK Independent House ', '3 BHK ApartmentAmberpet, Hyderabad',
#        '4 BHK Independent HouseMalakpet, Hyderabad',
#        '6 BHK Independent HouseMalakpet, Hyderabad',
#        '1 BHK ApartmentNallakunta, Hyderabad',
#        '3 BHK ApartmentSaroornagar, Hyderabad', '2 BHK ApartmentSa',
#        '2 BHK ApartmentNacharam, Hyderabad',
#        '3 BHK ApartmentNacharam, Hyderabad',
#        '1 BHK Independent FloorMalkajgiri, Hyderabad',
#        '3 BHK ApartmentPatancheru, Hyderabad', '3 BHK Independent Floor ',
#        '2 BHK Independent FloorNacharam, Hyderabad',
#        '3 BHK ApartmentHabsiguda, Hyderabad',
#        '2 BHK ApartmentHabsiguda, Hyderabad',
#        '1 BHK ApartmentTarnaka, Hyderabad', '5 BHK Independent HouseSa',
#        '4 BHK VillaKrishna Reddy Pet, Hyderabad',
#        '1 BHK ApartmentNacharam, Hyderabad',
#        '5 BHK Independent HouseMadhapur, Hyderabad',
#        '7 BHK Independent HouseAS Rao Nagar, Hyderabad',
#        '3 BHK ApartmentTarnaka, Hyderabad',
#        '2 BHK ApartmentKowkur, Hyderabad',
#        '3 BHK ApartmentHafeezpet, Hyderabad',
#        '2 BHK ApartmentIndresham, Hyderabad',
#        '2 BHK ApartmentManikonda, Hyderabad',
#        '4 BHK Independent HouseNagaram, Hyderabad',
#        '4 BHK Independent HouseVanasthalipuram, Hyderabad',
#        '3 BHK ApartmentHast',
#        '4 BHK Independent HouseLB Nagar, Hyderabad',
#        '2 BHK ApartmentAS Rao Nagar, Hyderabad',
#        '3 BHK Independent HouseShadnagar, Hyderabad',
#        '2 BHK Independent HouseShadnagar, Hyderabad',
#        '2 BHK ApartmentTarnaka, Hyderabad',
#        '4 BHK Independent FloorNacharam, Hyderabad',
#        '2 BHK Independent FloorTarnaka, Hyderabad',
#        '4 BHK Independent HouseNacharam, Hyderabad',
#        '3 BHK ApartmentHitech City, Hyderabad',
#        '3 BHK VillaMokila, Hyderabad', '3 BHK VillaKollur, Hyderabad',
#        '2 BHK ApartmentMokila, Hyderabad',
#        '2 BHK ApartmentShankarpally Road, Hyderabad',
#        '5 BHK ApartmentBegumpet, Hyderabad',
#        '2 BHK ApartmentKondapur, Hyderabad',
#        '2 BHK ApartmentBorabanda, Hyderabad',
#        '3 BHK VillaTukkuguda, Hyderabad', '4 BHK VillaKollur, Hyderabad',
#        '2 BHK ApartmentSaidabad, Hyderabad',
#        '2 BHK ApartmentKarmanghat, Hyderabad',
#        '2 BHK ApartmentChampapet, Hyderabad',
#        '3 BHK ApartmentChampapet, Hyderabad',
#        '3 BHK ApartmentKarmanghat, Hyderabad',
#        '3 BHK ApartmentSaidabad, Hyderabad',
#        '2 BHK ApartmentNeredmet, Hyderabad',
#        '5 BHK Independent HouseAmberpet, Hyderabad',
#        '3 BHK VillaMaheshwaram, Hyderabad', '3 BHK ApartmentAm',
#        '3 BHK Independent HouseAS Rao Nagar, Hyderabad',
#        '4 BHK VillaManikonda, Hyderabad',
#        '4 BHK VillaTellapur, Hyderabad',
#        '2 BHK ApartmentKompally, Hyderabad',
#        '3 BHK ApartmentSantoshnagar, Hyderabad',
#        '3 BHK ApartmentKhajaguda Nanakramguda Road, Hyderabad',
#        '2 BHK ApartmentKhajaguda Nanakramguda Road, Hyderabad',
#        '3 BHK ApartmentShaikpet, Hyderabad',
#        '10 BHK Independent HouseNagaram, Hyderabad',
#        '3 BHK VillaLB Nagar, Hyderabad',
#        '3 BHK VillaHayathnagar, Hyderabad',
#        '3 BHK Independent HouseNacharam, Hyderabad',
#        '3 BHK Independent FloorTarnaka, Hyderabad',
#        '4 BHK Independent HouseBollaram, Hyderabad',
#        '5 BHK VillaYapral, Hyderabad',
#        '2 BHK Independent FloorBegumpet, Hyderabad',
#        '4 BHK Independent HouseNeredmet, Hyderabad',
#        '2 BHK Independent HouseNeredmet, Hyderabad',
#        '8 BHK Independent HouseMeerpet, Hyderabad',
#        '2 BHK ApartmentKardhanur, Hyderabad',
#        '2 BHK ApartmentGhanpur, Hyderabad',
#        '4 BHK VillaNizampet, Hyderabad',
#        '3 BHK Independent HouseSuraram, Hyderabad',
#        '2 BHK ApartmentNagole, Hyderabad',
#        '3 BHK ApartmentKompally, Hyderabad',
#        '2 BHK ApartmentNarepally, Hyderabad',
#        '3 BHK ApartmentMansoorabad, Hyderabad',
#        '4 BHK VillaRaviryal, Hyderabad',
#        '3 BHK ApartmentJillelguda, Hyderabad',
#        '2 BHK ApartmentUppal, Hyderabad',
#        '4 BHK Independent HouseHitech City, Hyderabad',
#        '5 BHK Independent HouseBanjara Hills, Hyderabad',
#        '4 BHK Independent HouseBanjara Hills, Hyderabad',
#        '6 BHK Independent HouseJubilee Hills, Hyderabad',
#        '6 BHK Independent FloorAm',
#        '6 BHK Independent FloorMiyapur, Hyderabad',
#        '5 BHK Independent FloorMiyapur, Hyderabad',
#        '5 BHK Independent HouseMiyapur, Hyderabad',
#        '5 BHK VillaMiyapur, Hyderabad',
#        '5 BHK Independent HouseBachupally, Hyderabad',
#        '6 BHK Independent HouseMiyapur, Hyderabad',
#        '10 BHK Independent FloorMiyapur, Hyderabad',
#        '1 BHK ApartmentAmberpet, Hyderabad',
#        '3 BHK ApartmentMahadevpur Colony, Hyderabad',
#        '3 BHK VillaIndresham, Hyderabad',
#        '3 BHK Independent HouseMadhapur, Hyderabad',
#        '3 BHK ApartmentBowenpally, Hyderabad',
#        '2 BHK ApartmentDundigal, Hyderabad',
#        '3 BHK ApartmentSuchitra, Hyderabad',
#        '2 BHK ApartmentSuchitra, Hyderabad',
#        '1 BHK ApartmentMallampet, Hyderabad', '4 BHK VillaNars',
#        '3 BHK ApartmentWest Marredpally, Hyderabad',
#        '4 BHK Independent HouseKarkhana, Hyderabad',
#        '4 BHK Independent HouseTrimalgherry, Hyderabad',
#        '4 BHK VillaBowenpally, Hyderabad',
#        '4 BHK ApartmentKarkhana, Hyderabad',
#        '10 BHK Independent HouseBowenpally, Hyderabad',
#        '4 BHK ApartmentKondapur, Hyderabad',
#        '5 BHK VillaBowenpally, Hyderabad',
#        '8 BHK Independent HouseBanjara Hills, Hyderabad',
#        '5 BHK Independent HousePadmarao Nagar, Hyderabad',
#        '6 BHK VillaWest Marredpally, Hyderabad',
#        '9 BHK Independent HouseBanjara Hills, Hyderabad',
#        '3 BHK ApartmentKowkur, Hyderabad',
#        '4 BHK VillaKokapet, Hyderabad', '4 BHK VillaVatt',
#        '3 BHK ApartmentRajendra Nagar, Hyderabad',
#        '2 BHK Independent HouseManikonda, Hyderabad',
#        '3 BHK ApartmentPunjagutta, Hyderabad',
#        '3 BHK VillaVanasthalipuram, Hyderabad',
#        '3 BHK ApartmentNagole, Hyderabad',
#        '3 BHK ApartmentAS Rao Nagar, Hyderabad',
#        '9 BHK Independent HouseAmberpet, Hyderabad',
#        '2 BHK ApartmentDullapally, Hyderabad',
#        '3 BHK VillaAdibatla, Hyderabad',
#        '2 BHK ApartmentHitech City, Hyderabad',
#        '2 BHK ApartmentMahadevpur Colony, Hyderabad',
#        '4 BHK Independent HouseIsnapur, Hyderabad',
#        '3 BHK ApartmentPuppalaguda, Hyderabad',
#        '3 BHK ApartmentSomajiguda, Hyderabad',
#        '5 BHK Independent FloorJubilee Hills, Hyderabad',
#        '5 BHK Independent HouseEast Marredpally, Hyderabad',
#        '4 BHK Independent HouseSa',
#        '3 BHK Independent FloorBanjara Hills, Hyderabad',
#        '5 BHK Independent HouseJubilee Hills, Hyderabad',
#        '3 BHK Independent HouseYellareddy Guda, Hyderabad',
#        '2 BHK Independent HousePedda Amberpet, Hyderabad',
#        '1 BHK ApartmentShankarpally Road, Hyderabad',
#        '3 BHK VillaShankarpally Road, Hyderabad',
#        '4 BHK ApartmentSomajiguda, Hyderabad',
#        '2 BHK ApartmentJillelguda, Hyderabad',
#        '3 BHK ApartmentVanasthalipuram, Hyderabad',
#        '3 BHK Independent FloorNagole, Hyderabad',
#        '3 BHK Independent FloorLB Nagar, Hyderabad',
#        '8 BHK Independent HouseMansoorabad, Hyderabad',
#        '7 BHK Independent HouseMansoorabad, Hyderabad',
#        '2 BHK ApartmentShamshabad, Hyderabad',
#        '3 BHK ApartmentShamshabad, Hyderabad',
#        '1 BHK ApartmentRamachandra Puram, Hyderabad',
#        '4 BHK VillaKondakal, Hyderabad',
#        '4 BHK VillaNagulapalli, Hyderabad',
#        '2 BHK ApartmentKokapet, Hyderabad', '3 BHK VillaPati, Hyderabad',
#        '3 BHK ApartmentManchirevula, Hyderabad', '3 BHK ApartmentNars',
#        '3 BHK ApartmentNeknampur, Hyderabad',
#        '2 BHK ApartmentNeknampur, Hyderabad', '3 BHK VillaNars',
#        '3 BHK ApartmentTellapur, Hyderabad',
#        '2 BHK ApartmentManchirevula, Hyderabad',
#        '4 BHK VillaShankarpally Road, Hyderabad',
#        '4 BHK VillaKardhanur, Hyderabad',
#        '4 BHK VillaNandigama, Hyderabad', '4 BHK VillaBhanur, Hyderabad',
#        '4 BHK VillaPati, Hyderabad',
#        '2 BHK Independent HouseShamshabad, Hyderabad',
#        '4 BHK Independent HouseSaroornagar, Hyderabad',
#        '4 BHK ApartmentNanakramguda, Hyderabad',
#        '2 BHK ApartmentNanakramguda, Hyderabad',
#        '4 BHK Apartmentraidurgam, Hyderabad',
#        '3 BHK ApartmentBalanagar, Hyderabad',
#        '3 BHK ApartmentGandipet, Hyderabad',
#        '3 BHK ApartmentNanakramguda, Hyderabad',
#        '3 BHK VillaVelimela, Hyderabad',
#        '4 BHK ApartmentHitech City, Hyderabad',
#        '2 BHK Independent HouseMedchal, Hyderabad',
#        '4 BHK Independent HouseMedchal, Hyderabad',
#        '5 BHK Independent HouseManikonda, Hyderabad',
#        '3 BHK Villamuthangi, Hyderabad',
#        '3 BHK VillaRameshwaram Banda, Hyderabad',
#        '3 BHK VillaBachupally, Hyderabad',
#        '5 BHK VillaShankarpally Road, Hyderabad',
#        '1 BHK Independent HouseShadnagar, Hyderabad',
#        '5 BHK VillaTellapur, Hyderabad',
#        '10 BHK Independent HouseLakdikapul, Hyderabad',
#        '2 BHK ApartmentAdarsh Nagar, Hyderabad',
#        '5 BHK Independent HouseDammaiguda, Hyderabad',
#        '2 BHK ApartmentSafilguda, Hyderabad',
#        '5 BHK ApartmentNanakramguda, Hyderabad',
#        '4 BHK VillaKondapur, Hyderabad',
#        '4 BHK VillaHitech City, Hyderabad', '5 BHK VillaNars',
#        '5 BHK VillaManchirevula, Hyderabad', '7 BHK Villa ',
#        '5 BHK VillaKondapur, Hyderabad',
#        '4 BHK ApartmentGachibowli, Hyderabad',
#        '3 BHK Independent HouseKurmaguda, Hyderabad',
#        '7 BHK Independent HouseHyderguda, Hyderabad',
#        '4 BHK Independent Floor ',
#        '6 BHK Independent HouseKoti, Hyderabad',
#        '3 BHK ApartmentHyderguda, Hyderabad',
#        '2 BHK Independent Housechandrayangutta, Hyderabad',
#        '10 BHK Independent HouseHyderguda, Hyderabad',
#        '3 BHK Independent HouseBaba Nagar, Hyderabad',
#        '2 BHK ApartmentAsif Nagar North, Hyderabad',
#        '2 BHK ApartmentAsif Nagar, Hyderabad',
#        '3 BHK Independent HouseNawab Saheb Kunta, Hyderabad',
#        '6 BHK Independent HouseHimayat Nagar, Hyderabad',
#        '5 BHK Independent HouseHimayat Nagar, Hyderabad',
#        '2 BHK Independent HouseSafilguda, Hyderabad',
#        '2 BHK Independent FloorAS Rao Nagar, Hyderabad',
#        '5 BHK Independent HouseSafilguda, Hyderabad',
#        '5 BHK Independent HouseAS Rao Nagar, Hyderabad',
#        '5 BHK Independent HouseNeredmet, Hyderabad',
#        '3 BHK Independent HouseSafilguda, Hyderabad',
#        '3 BHK Independent HouseSa',
#        '3 BHK Independent HouseKapra, Hyderabad',
#        '6 BHK Independent HouseAS Rao Nagar, Hyderabad',
#        '2 BHK Independent HouseKapra, Hyderabad',
#        '4 BHK Independent HouseAS Rao Nagar, Hyderabad',
#        '4 BHK VillaGachibowli, Hyderabad',
#        '3 BHK VillaRamoji Film city, Hyderabad',
#        '3 BHK Independent HousePuppalaguda, Hyderabad',
#        '2 BHK ApartmentShaikpet, Hyderabad',
#        '5 BHK VillaManikonda, Hyderabad',
#        '3 BHK Independent HousePocharam, Hyderabad',
#        '2 BHK Independent HouseMalkajgiri, Hyderabad',
#        '2 BHK Independent HouseAS Rao Nagar, Hyderabad',
#        '4 BHK Independent HouseBegumpet, Hyderabad',
#        '4 BHK Independent HouseMalkajgiri, Hyderabad',
#        '1 BHK Independent HouseTarnaka, Hyderabad',
#        '2 BHK ApartmentWest Marredpally, Hyderabad',
#        '3 BHK Independent HouseNeredmet, Hyderabad',
#        '4 BHK VillaTrimalgherry, Hyderabad',
#        '2 BHK Independent HouseTrimalgherry, Hyderabad',
#        '4 BHK Independent HouseMiyapur, Hyderabad',
#        '3 BHK VillaNizampet, Hyderabad',
#        '8 BHK Independent HouseGaddi Annaram, Hyderabad',
#        '3 BHK ApartmentEast Marredpally, Hyderabad',
#        '4 BHK VillaBanjara Hills, Hyderabad',
#        '4 BHK Independent HouseHimayat Nagar, Hyderabad',
#        '4 BHK Independent HousePragathi Nagar Kukatpally, Hyderabad',
#        '7 BHK Independent HouseSri Nagar Colony, Hyderabad',
#        '4 BHK VillaJubilee Hills, Hyderabad',
#        '4 BHK VillaMadhapur, Hyderabad',
#        '2 BHK ApartmentNagulapalli, Hyderabad',
#        '3 BHK VillaShadnagar, Hyderabad', '2 BHK ApartmentHast',
#        '2 BHK ApartmentHayathnagar, Hyderabad',
#        '2 BHK ApartmentMeerpet, Hyderabad',
#        '3 BHK ApartmentGachibowli, Hyderabad',
#        '2 BHK ApartmentKrishna Reddy Pet, Hyderabad',
#        '2 BHK Independent HouseAm',
#        '2 BHK Independent HouseRampally, Hyderabad',
#        '4 BHK Independent HouseAm',
#        '4 BHK Independent HouseNagole, Hyderabad',
#        '3 BHK Independent HouseBoduppal, Hyderabad',
#        '3 BHK Independent Housemuthangi, Hyderabad',
#        '4 BHK Independent FloorNagole, Hyderabad',
#        '3 BHK Independent HouseIndresham, Hyderabad',
#        '2 BHK Independent HouseNagole, Hyderabad',
#        '3 BHK Independent FloorUppal, Hyderabad',
#        '2 BHK Independent HouseRambagh Colony, Hyderabad',
#        '2 BHK Independent HouseUppal, Hyderabad',
#        '3 BHK ApartmentPadmarao Nagar, Hyderabad',
#        '5 BHK VillaBandlaguda Jagir, Hyderabad',
#        '5 BHK VillaAppa Junction, Hyderabad',
#        '4 BHK Independent HouseBoduppal, Hyderabad',
#        '3 BHK ApartmentGajularamaram, Hyderabad',
#        '4 BHK Independent HousePatancheru, Hyderabad',
#        '2 BHK ApartmentPati, Hyderabad',
#        '3 BHK ApartmentIndresham, Hyderabad',
#        '1 BHK Independent HousePatancheru, Hyderabad',
#        '2 BHK Independent HousePatancheru, Hyderabad',
#        '3 BHK ApartmentYousufguda, Hyderabad',
#        '3 BHK ApartmentRamachandra Puram, Hyderabad',
#        '6 BHK VillaKandukur, Hyderabad', '4 BHK VillaSeril',
#        '4 BHK VillaKandukur, Hyderabad',
#        '4 BHK VillaPocharam South Hyderabad, Hyderabad',
#        '1 BHK ApartmentMokila, Hyderabad'], dtype=object)

# %%
df2['property_type'] = df2['property_type'].str.extract(
    r'(Apartment|Villa|Independent House|Independent Floor)', 
    expand=False
)
df2['price_in_crores'] = df2['price_in_crores'].round(2)
df2.head(10)

df2['bedrooms'] = df2['bedrooms'].astype(int)
df2.shape
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_6888\606804912.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['property_type'] = df2['property_type'].str.extract(
# C:\Users\rohit\AppData\Local\Temp\ipykernel_6888\606804912.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['price_in_crores'] = df2['price_in_crores'].round(2)
# C:\Users\rohit\AppData\Local\Temp\ipykernel_6888\606804912.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['bedrooms'] = df2['bedrooms'].astype(int)
# (4099, 9)

# %%
df3 = df2.copy()
exclude_values = ['Resale ', 'New ', '1 Bathrooms', '2 Bathrooms', '3 Bathrooms', '4 Bathrooms',
                  '5 Bathrooms', '6 Bathrooms', '7 Bathrooms', '8 Bathrooms',
                  '9 Bathrooms', '10 Bathrooms', '11 Bathrooms', '12 Bathrooms']
df3 = df3[~df3['age_of_property'].isin(exclude_values)]
df3
# Out:
#                                 builder_name       city  \
# 0     Theme Ambience InfrastructuresBUILDER0  Hyderabad
# 1                   Elemental RealtyBUILDER0  Hyderabad
# 2        R V Nirmaan Private LimitedBUILDER0  Hyderabad
# 3                   Risinia BuildersBUILDER0  Hyderabad
# 4                  Cyber City OrianaBUILDER0  Hyderabad
# ...                                      ...        ...
# 5953                    TSR PROPERTIESAGENT0  Hyderabad
# 5954                    TSR PROPERTIESAGENT0  Hyderabad
# 5955                    TSR PROPERTIESAGENT0  Hyderabad
# 5956                    TSR PROPERTIESAGENT0  Hyderabad
# 5957                    TSR PROPERTIESAGENT0  Hyderabad
#
#                        locality property_type  price_in_crores  area_in_sqft  \
# 0                       Attapur     Apartment             1.50          2090
# 1                    Patancheru         Villa             1.48          1930
# 2                       Miyapur     Apartment             1.27          1967
# 3     Pragathi Nagar Kukatpally     Apartment             0.73          1312
# 4                    Kukatpally     Apartment             1.28          1480
# ...                         ...           ...              ...           ...
# 5953                  Manikonda     Apartment             1.10          1750
# 5954               Nanakramguda     Apartment             1.53          2230
# 5955               Nanakramguda     Apartment             0.91          1315
# 5956               Nanakramguda     Apartment             1.53          2230
# 5957               Nanakramguda     Apartment             0.91          1315
#
#      construction_status         age_of_property  bedrooms
# 0     Under Construction  Possession by Dec 2024         3
# 1     Under Construction  Possession by Nov 2024         4
# 2     Under Construction  Possession by Nov 2024         3
# 3     Under Construction  Possession by May 2025         2
# 4     Under Construction  Possession by Nov 2025         3
# ...                  ...                     ...       ...
# 5953       Ready to move             4 years old         3
# 5954  Under Construction  Possession by Nov 2026         3
# 5955  Under Construction  Possession by Nov 2026         2
# 5956  Under Construction  Possession by Nov 2026         3
# 5957  Under Construction  Possession by Nov 2026         2
#
# [2872 rows x 9 columns]

# %% [markdown]
# <h2 style='color:#007fd4' align='left'>Handling age of property column</h2>

# %%
df3.age_of_property.unique()
# Out:
# array(['Possession by Dec 2024', 'Possession by Nov 2024',
#        'Possession by May 2025', 'Possession by Nov 2025',
#        'Possession by Nov 2023', 'Possession by Dec 2025',
#        'Possession by Feb 2026', 'Possession by Nov 2026',
#        'Possession by May 2027', '0 - 1 year old', '2 - 3 years old',
#        'Possession by Jun 2025', 'Possession by Aug 2025',
#        'Possession by Oct 2023', 'Possession by Sep 2026',
#        '6 - 7 years old', 'Possession by Jan 2027',
#        'Possession by Sep 2023', '3 - 4 years old',
#        'Possession by Mar 2024', '4 - 5 years old', '1 - 2 years old',
#        'Possession by May 2024', 'Possession by Oct 2024',
#        'Possession by May 2023', 'Possession by Apr 2025',
#        'Possession by Feb 2024', 'Possession by Nov 2027',
#        'Possession by Aug 2024', 'Possession by Feb 2025',
#        '5 - 6 years old', 'Possession by Nov 2022',
#        'Possession by Dec 2023', 'Possession by Jan 2025',
#        '10 - 11 years old', '8 - 9 years old', 'Possession by Dec 2022',
#        'Possession by Jul 2028', 'Possession by Dec 2027', '2 years old',
#        '7 - 8 years old', 'Possession by Feb 2023', '14 - 15 years old',
#        'Possession by Jul 2024', '7 years old', 'Possession by Sep 2025',
#        '9 - 10 years old', 'Possession by Dec 2026',
#        'Possession by Sep 2024', 'Possession by Jun 2027',
#        'Possession by Apr 2026', 'Possession by Jun 2023',
#        'Possession by Jun 2024', 'Possession by Jun 2026',
#        'Possession by Oct 2027', 'Possession by Dec 2028',
#        'Possession by Oct 2026', 'Possession by Jul 2025',
#        'Possession by Oct 2025', 'Possession by Feb 2027',
#        'Possession by Aug 2026', '5 years old', 'Possession by Apr 2028',
#        'Possession by Mar 2025', 'Possession by Mar 2028',
#        'Possession by Sep 2029', 'Possession by Apr 2023', '4 years old',
#        'Possession by Apr 2027', 'Possession by Jul 2026',
#        'Possession by Mar 2026', 'Possession by Aug 2023',
#        'Possession by Aug 2028', 'Possession by Sep 2028',
#        'Possession by Jan 2028', 'Possession by Feb 2020',
#        'Possession by Apr 2024', '12 - 13 years old',
#        'Possession by Sep 2027', 'Possession by Jan 2026',
#        'Possession by Jun 2029', 'Possession by Nov 2020',
#        '13 - 14 years old', '1 year old', 'Possession by Jan 2023',
#        '11 - 12 years old', '20 - 21 years old', '11 years old',
#        'Possession by Mar 2027', 'Possession by Oct 2022', '8 years old',
#        'Possession by Feb 2028', '18 - 19 years old',
#        'Possession by Dec 1899', 'Possession by Jan 2024',
#        'Possession by Aug 2022', 'Possession by Jul 2022',
#        'Possession by May 2026', 'Possession by Nov 2028'], dtype=object)

# %%
df4 = df3.copy()

# %%
def clean_age_property(value):
    import re
    
    if 'Possession by' in str(value):
        year_match = re.search(r'20(\d{2})', str(value))
        if year_match:
            possession_year = '20' + year_match.group(1)  
            return possession_year
    
    number_range = re.search(r'(\d+)\s*-\s*(\d+)', str(value))
    single_number = re.search(r'(\d+)', str(value))
    
    if number_range:
        return f"{number_range.group(1)} - {number_range.group(2)}"
    elif single_number:
        return single_number.group(1)
    else:
        return value

df4['age_of_property'] = df4['age_of_property'].apply(clean_age_property)

df4.age_of_property.unique()
# Out:
# array(['2024', '2025', '2023', '2026', '2027', '0 - 1', '2 - 3', '6 - 7',
#        '3 - 4', '4 - 5', '1 - 2', '5 - 6', '2022', '10 - 11', '8 - 9',
#        '2028', '2', '7 - 8', '14 - 15', '7', '9 - 10', '5', '2029', '4',
#        '2020', '12 - 13', '13 - 14', '1', '11 - 12', '20 - 21', '11', '8',
#        '18 - 19', '1899'], dtype=object)

# %%
def avg_property_age(x):
    tokens = x.split('-')
    if len(tokens) == 2:
        return (float(tokens[0])+float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
avg_property_age('8 - 9')
# Out:
# 8.5

# %%
df5 = df4.copy()
df5.age_of_property = df5.age_of_property.apply(lambda x: avg_property_age(str(x)))
df5.head()
# Out:
#                              builder_name       city  \
# 0  Theme Ambience InfrastructuresBUILDER0  Hyderabad
# 1                Elemental RealtyBUILDER0  Hyderabad
# 2     R V Nirmaan Private LimitedBUILDER0  Hyderabad
# 3                Risinia BuildersBUILDER0  Hyderabad
# 4               Cyber City OrianaBUILDER0  Hyderabad
#
#                     locality property_type  price_in_crores  area_in_sqft  \
# 0                    Attapur     Apartment             1.50          2090
# 1                 Patancheru         Villa             1.48          1930
# 2                    Miyapur     Apartment             1.27          1967
# 3  Pragathi Nagar Kukatpally     Apartment             0.73          1312
# 4                 Kukatpally     Apartment             1.28          1480
#
#   construction_status  age_of_property  bedrooms
# 0  Under Construction           2024.0         3
# 1  Under Construction           2024.0         4
# 2  Under Construction           2024.0         3
# 3  Under Construction           2025.0         2
# 4  Under Construction           2025.0         3

# %%
df6 = df5.copy()
df6['age_of_property'] = df6['age_of_property'].apply(lambda x: 2025 - x if x > 1800 else x)
df6.shape
# Out:
# (2872, 9)

# %%
df6 = df6[df6['age_of_property']<120]
df6.shape
# Out:
# (2871, 9)

# %%
df6['age_of_property'] = df6.age_of_property.astype(int)
df6.age_of_property.describe()
# Out:
# count    2871.000000
# mean        1.145942
# std         2.662414
# min        -4.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max        20.000000
# Name: age_of_property, dtype: float64

# %%
df6['locality'] = df6['locality'].str.strip()
df6.locality.value_counts(ascending=False).head()
# Out:
# locality
# Kollur         158
# Miyapur        133
# Narsingi       129
# Hitech City    114
# Kokapet        114
# Name: count, dtype: int64

# %% [markdown]
# <h2 style="color:#007fd4">Outlier Removal Using Business Logic</h2>

# %%
df6[df6['area_in_sqft']/df6['bedrooms']<300]
# Out:
#                       builder_name       city   locality      property_type  \
# 70            sellerVERIFIED OWNER  Hyderabad  Habsiguda          Apartment
# 2266  Om Sri Sai Ram RentalsAGENT0  Hyderabad   Nacharam  Independent Floor
# 3362  Om Sri Sai Ram RentalsAGENT0  Hyderabad   Nacharam  Independent Floor
# 4135           MG PropertiesAGENT0  Hyderabad   Madhapur          Apartment
# 4466        MMAB Real EstateAGENT0  Hyderabad  Kurmaguda  Independent House
#
#       price_in_crores  area_in_sqft construction_status  age_of_property  \
# 70               0.55          1051       Ready to move                3
# 2266             1.50          1000       Ready to move                7
# 3362             1.50          1000       Ready to move                7
# 4135             2.50           240       Ready to move               10
# 4466             0.20           750       Ready to move                4
#
#       bedrooms
# 70           4
# 2266         4
# 3362         4
# 4135         1
# 4466         3

# %%
df7 = df6[~(df6['area_in_sqft']/df6['bedrooms']<300)]
df7.shape
# Out:
# (2866, 9)

# %% [markdown]
# <h2 style="color:#007fd4">Feature Engineering: Adding price per sqft column</h2>

# %%
df7['price_per_sqft'] = df7['price_in_crores']*10000000/df7['area_in_sqft']
df7
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_6888\2876756174.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7['price_per_sqft'] = df7['price_in_crores']*10000000/df7['area_in_sqft']
#                                 builder_name       city  \
# 0     Theme Ambience InfrastructuresBUILDER0  Hyderabad
# 1                   Elemental RealtyBUILDER0  Hyderabad
# 2        R V Nirmaan Private LimitedBUILDER0  Hyderabad
# 3                   Risinia BuildersBUILDER0  Hyderabad
# 4                  Cyber City OrianaBUILDER0  Hyderabad
# ...                                      ...        ...
# 5953                    TSR PROPERTIESAGENT0  Hyderabad
# 5954                    TSR PROPERTIESAGENT0  Hyderabad
# 5955                    TSR PROPERTIESAGENT0  Hyderabad
# 5956                    TSR PROPERTIESAGENT0  Hyderabad
# 5957                    TSR PROPERTIESAGENT0  Hyderabad
#
#                        locality property_type  price_in_crores  area_in_sqft  \
# 0                       Attapur     Apartment             1.50          2090
# 1                    Patancheru         Villa             1.48          1930
# 2                       Miyapur     Apartment             1.27          1967
# 3     Pragathi Nagar Kukatpally     Apartment             0.73          1312
# 4                    Kukatpally     Apartment             1.28          1480
# ...                         ...           ...              ...           ...
# 5953                  Manikonda     Apartment             1.10          1750
# 5954               Nanakramguda     Apartment             1.53          2230
# 5955               Nanakramguda     Apartment             0.91          1315
# 5956               Nanakramguda     Apartment             1.53          2230
# 5957               Nanakramguda     Apartment             0.91          1315
#
#      construction_status  age_of_property  bedrooms  price_per_sqft
# 0     Under Construction                1         3     7177.033493
# 1     Under Construction                1         4     7668.393782
# 2     Under Construction                1         3     6456.532791
# 3     Under Construction                0         2     5564.024390
# 4     Under Construction                0         3     8648.648649
# ...                  ...              ...       ...             ...
# 5953       Ready to move                4         3     6285.714286
# 5954  Under Construction               -1         3     6860.986547
# 5955  Under Construction               -1         2     6920.152091
# 5956  Under Construction               -1         3     6860.986547
# 5957  Under Construction               -1         2     6920.152091
#
# [2866 rows x 10 columns]

# %%
df7.price_per_sqft.describe()
# Out:
# count     2866.000000
# mean      7305.679027
# std       2998.442533
# min       1750.000000
# 25%       5608.769567
# 50%       6751.273941
# 75%       8289.474611
# max      40909.090909
# Name: price_per_sqft, dtype: float64

# %% [markdown]
# <h2 style='color:#007fd4'>Outlier Removal Using Standard Deviation and Mean</h2>

# %%
def remove_pps_outliers(df):
    df_out = pd.DataFrame()
    for key, subdf in df.groupby('locality'):
        m = np.mean(subdf.price_per_sqft)
        st = np.std(subdf.price_per_sqft)
        reduced_df = subdf[(subdf.price_per_sqft>(m-st)) & (subdf.price_per_sqft<=(m+st))]
        df_out = pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out
df8 = remove_pps_outliers(df7)
df8.shape
# Out:
# (2238, 10)

# %% [markdown]
# **Checking for a given location how does the 2 bedrooms and 3 bedrooms property prices look like**

# %%
# def plot_scatter_chart(df,locality):
#     bedrooms2 = df[(df.locality==locality) & (df.bedrooms==2)]
#     bedrooms3 = df[(df.locality==locality) & (df.bedrooms==3)]
#     matplotlib.rcParams['figure.figsize'] = (15,10)
#     plt.scatter(bedrooms2.area_in_sqft,bedrooms2.price_in_crores,color='blue',label='2 Bedrooms', s=50)
#     plt.scatter(bedrooms3.area_in_sqft,bedrooms3.price_in_crores,marker='+', color='green',label='3 Bedrooms', s=50)
#     plt.xlabel("Total Square Feet Area")
#     plt.ylabel("Price (Crore Indian Rupees)")
#     plt.title(locality)
#     plt.legend()
    
# plot_scatter_chart(df8,"Kompally")


import plotly.express as px

def plot_scatter_chart(df, locality):
    bedrooms2 = df[(df.locality == locality) & (df.bedrooms == 2)]
    bedrooms3 = df[(df.locality == locality) & (df.bedrooms == 3)]
    
    plot_df = pd.concat([bedrooms2, bedrooms3])
    
    fig = px.scatter(
        plot_df,
        x="area_in_sqft",
        y="price_in_crores",
        color=plot_df["bedrooms"].astype(str) + " Bedrooms",
        title=locality,
        labels={
            "area_in_sqft": "Total Square Feet Area",
            "price_in_crores": "Price (Crore Indian Rupees)"
        },
        symbol="bedrooms", 
        size_max=10
    )
    
    fig.update_traces(marker=dict(size=10, opacity=0.8))
    fig.update_layout(
        legend_title_text="Bedroom Type",
        width=1000,
        height=550
    )
    
    fig.show()

plot_scatter_chart(df8, "Kompally")

# %%
def remove_bedroom_outliers(df):
    exclude_indices = np.array([])
    for location, location_df in df.groupby('locality'):
        bedrooms_stats = {}
        for bedroom, bedroom_df in location_df.groupby('bedrooms'):
            bedrooms_stats[bedroom] = {
                'mean': np.mean(bedroom_df.price_per_sqft),
                'std': np.std(bedroom_df.price_per_sqft),
                'count': bedroom_df.shape[0]
            }
        for bedroom, bedroom_df in location_df.groupby('bedrooms'):
            stats = bedrooms_stats.get(bedroom-1)
            if stats and stats['count']>5:
                exclude_indices = np.append(exclude_indices, bedroom_df[bedroom_df.price_per_sqft<(stats['mean'])].index.values)
    return df.drop(exclude_indices,axis='index')
df9 = remove_bedroom_outliers(df8)
df9.shape
# Out:
# (1850, 10)

# %%
plot_scatter_chart(df9, "Kompally")

# %%
df9.price_in_crores.describe()
# Out:
# count    1850.000000
# mean        1.564573
# std         1.314433
# min         0.270000
# 25%         0.860000
# 50%         1.255000
# 75%         1.770000
# max        17.600000
# Name: price_in_crores, dtype: float64

# %%
df9.columns
# Out:
# Index(['builder_name', 'city', 'locality', 'property_type', 'price_in_crores',
#        'area_in_sqft', 'construction_status', 'age_of_property', 'bedrooms',
#        'price_per_sqft'],
#       dtype='object')

# %%
x = df9.drop(['builder_name', 'city', 'construction_status', 'price_in_crores', 'price_per_sqft'], axis=1)
y = df9['price_in_crores']

# %%
loc_dummies = pd.get_dummies(x['locality'])
locality_dummies = loc_dummies.drop('Yapral',axis='columns')
locality_dummies.head()
# Out:
#    AS Rao Nagar  Abids  Adibatla  Ameenpur  Ameerpet  \
# 0          True  False     False     False     False
# 1          True  False     False     False     False
# 2          True  False     False     False     False
# 3          True  False     False     False     False
# 4          True  False     False     False     False
#
#    Appa Junction Peerancheru  Attapur  Bachupally  Balanagar  Balapur  ...  \
# 0                      False    False       False      False    False  ...
# 1                      False    False       False      False    False  ...
# 2                      False    False       False      False    False  ...
# 3                      False    False       False      False    False  ...
# 4                      False    False       False      False    False  ...
#
#    Shankarpalli  Shankarpally Road  Sultanpur  Tellapur  Trimalgherry  \
# 0         False              False      False     False         False
# 1         False              False      False     False         False
# 2         False              False      False     False         False
# 3         False              False      False     False         False
# 4         False              False      False     False         False
#
#    Tukkuguda  Turkayamjal  Uppal Kalan  Vanasthalipuram  Velmala
# 0      False        False        False            False    False
# 1      False        False        False            False    False
# 2      False        False        False            False    False
# 3      False        False        False            False    False
# 4      False        False        False            False    False
#
# [5 rows x 106 columns]

# %%
pro_type_dummies = pd.get_dummies(x['property_type'])
property_type_dummies = pro_type_dummies.drop('Independent Floor',axis='columns')
property_type_dummies.head()
# Out:
#    Apartment  Independent House  Villa
# 0      False               True  False
# 1       True              False  False
# 2      False               True  False
# 3       True              False  False
# 4       True              False  False

# %%
X = pd.concat([x.drop(['locality', 'property_type'], axis=1), locality_dummies, property_type_dummies], axis=1)
X
# Out:
#       area_in_sqft  age_of_property  bedrooms  AS Rao Nagar  Abids  Adibatla  \
# 0             5500                7         7          True  False     False
# 1             1100                7         2          True  False     False
# 2             1500                7         3          True  False     False
# 3             1400                7         3          True  False     False
# 4              950                7         2          True  False     False
# ...            ...              ...       ...           ...    ...       ...
# 2233          3200                1         4         False  False     False
# 2234          3900                1         4         False  False     False
# 2235          3600                1         4         False  False     False
# 2236          2780                0         3         False  False     False
# 2237          1359                8         2         False  False     False
#
#       Ameenpur  Ameerpet  Appa Junction Peerancheru  Attapur  ...  Tellapur  \
# 0        False     False                      False    False  ...     False
# 1        False     False                      False    False  ...     False
# 2        False     False                      False    False  ...     False
# 3        False     False                      False    False  ...     False
# 4        False     False                      False    False  ...     False
# ...        ...       ...                        ...      ...  ...       ...
# 2233     False     False                      False    False  ...     False
# 2234     False     False                      False    False  ...     False
# 2235     False     False                      False    False  ...     False
# 2236     False     False                      False    False  ...     False
# 2237     False     False                      False    False  ...     False
#
#       Trimalgherry  Tukkuguda  Turkayamjal  Uppal Kalan  Vanasthalipuram  \
# 0            False      False        False        False            False
# 1            False      False        False        False            False
# 2            False      False        False        False            False
# 3            False      False        False        False            False
# 4            False      False        False        False            False
# ...            ...        ...          ...          ...              ...
# 2233         False      False        False        False            False
# 2234         False      False        False        False            False
# 2235         False      False        False        False            False
# 2236         False      False        False        False            False
# 2237         False      False        False        False            False
#
#       Velmala  Apartment  Independent House  Villa
# 0       False      False               True  False
# 1       False       True              False  False
# 2       False      False               True  False
# 3       False       True              False  False
# 4       False       True              False  False
# ...       ...        ...                ...    ...
# 2233     True      False              False   True
# 2234     True      False              False   True
# 2235     True      False              False   True
# 2236    False       True              False  False
# 2237    False       True              False  False
#
# [1850 rows x 112 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(X_train, y_train)
lr_clf.score(X_test, y_test)
# Out:
# 0.9414584010772888

# %%
from sklearn.tree import DecisionTreeRegressor
dt_clf = DecisionTreeRegressor(criterion='friedman_mse', splitter='best')
dt_clf.fit(X_train, y_train)
dt_clf.score(X_test, y_test)
# Out:
# 0.9716283571949381

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(LinearRegression(), X, y, cv=cv)
# Out:
# array([0.94607021, 0.9517526 , 0.94643653, 0.94875666, 0.9550611 ])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
import numpy as np

def find_and_eval_models(X_train, y_train, X_test, y_test, cv=cv):
    algos = {
        'linear_regression': {
            'model': LinearRegression(),
            'params': {'fit_intercept': [True, False]}
        },
        'lasso': {
            'model': Lasso(max_iter=10000),
            'params': {'alpha': [0.01, 0.1, 1.0]}
        },
        'ridge': {
            'model': Ridge(),
            'params': {'alpha': [0.1, 1.0, 10.0]}
        },
        'elasticnet': {
            'model': ElasticNet(max_iter=10000),
            'params': {'alpha': [0.01, 0.1, 1.0], 'l1_ratio': [0.2, 0.5, 0.8]}
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {'criterion': ['squared_error','friedman_mse'], 'splitter': ['best','random']}
        },
        'random_forest': {
            'model': RandomForestRegressor(random_state=0),
            'params': {'n_estimators': [50,100], 'max_depth': [None, 10]}
        },
        'gradient_boosting': {
            'model': GradientBoostingRegressor(random_state=0),
            'params': {'n_estimators': [100], 'learning_rate': [0.1, 0.05], 'max_depth':[3,5]}
        },
        'knn': {
            'model': KNeighborsRegressor(),
            'params': {'n_neighbors': [3,5]}
        }
    }

    results = []
    for name, cfg in algos.items():
        gs = GridSearchCV(cfg['model'], cfg['params'], cv=cv, n_jobs=-1, return_train_score=False)
        gs.fit(X_train, y_train)
        best = gs.best_estimator_
        y_pred = best.predict(X_test)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        results.append({
            'model': name,
            'best_cv_score': gs.best_score_,
            'test_r2': best.score(X_test, y_test),
            'test_rmse': rmse,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(results).sort_values(by='test_r2', ascending=False)

res_df = find_and_eval_models(X_train, y_train, X_test, y_test)
res_df
# Out:
#                model  best_cv_score   test_r2  test_rmse  \
# 6  gradient_boosting       0.967858  0.973231   0.217771
# 5      random_forest       0.950801  0.972949   0.218915
# 4      decision_tree       0.946958  0.972211   0.221880
# 2              ridge       0.941248  0.941568   0.321740
# 0  linear_regression       0.941526  0.939953   0.326158
# 3         elasticnet       0.833470  0.870291   0.479365
# 1              lasso       0.845853  0.866696   0.485963
# 7                knn       0.781150  0.794886   0.602809
#
#                                          best_params
# 6  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# 5           {'max_depth': None, 'n_estimators': 100}
# 4  {'criterion': 'squared_error', 'splitter': 'be...
# 2                                     {'alpha': 0.1}
# 0                           {'fit_intercept': False}
# 3                   {'alpha': 0.01, 'l1_ratio': 0.2}
# 1                                    {'alpha': 0.01}
# 7                                 {'n_neighbors': 3}

# %%
rf_model = RandomForestRegressor(max_depth=None, n_estimators=100)
rf_model.fit(X_train, y_train)
rf_model.score(X_test, y_test)
# Out:
# 0.9727243825278595

# %%
X.columns
# Out:
# Index(['area_in_sqft', 'age_of_property', 'bedrooms', 'AS Rao Nagar', 'Abids',
#        'Adibatla', 'Ameenpur', 'Ameerpet', 'Appa Junction Peerancheru',
#        'Attapur',
#        ...
#        'Tellapur', 'Trimalgherry', 'Tukkuguda', 'Turkayamjal', 'Uppal Kalan',
#        'Vanasthalipuram', 'Velmala', 'Apartment', 'Independent House',
#        'Villa'],
#       dtype='object', length=112)

# %%
def predict_cost(locality, property_type, area_in_sqft, age_of_property, bedrooms):
    loc_index = np.where(X.columns == locality)[0][0]
    pro_index = np.where(X.columns == property_type)[0][0]

    z = np.zeros(len(X.columns))
    z[0] = area_in_sqft
    z[1] = age_of_property
    z[2] = bedrooms

    if loc_index >= 0:
        z[loc_index] = 1
    if pro_index >= 0:
        z[pro_index] = 1

    return rf_model.predict([z])[0]

# %%
X.value_counts()
# Out:
# area_in_sqft  age_of_property  bedrooms  AS Rao Nagar  Abids  Adibatla  Ameenpur  Ameerpet  Appa Junction Peerancheru  Attapur  Bachupally  Balanagar  Balapur  Bandlaguda Jagir  Banjara Hills  Beeramguda  Begumpet  Bolarum  Bongloor  Bowenpally  Bowrampet  Chandanagar  Gachibowli  Gagillapur  Gajularamaram  Gajulramaram Kukatpally  Gandi Maisamma  Gandipet  Gopanpally  Gowdavalli  Gundlapochampally  Harshaguda  Hayathnagar  Hitech City  Hyder Nagar  Indresham  Isnapur  Jeedimetla  Kadthal  Kardhanur  Karwan  Khajaguda Nanakramguda Road  Kismatpur  Kokapet  Kollur  Kompally  Kondapur  Kowkur  Krishna Reddy Pet  Kukatpally  Kushaiguda  LB Nagar  Laxmiguda  Madhapur  Mahadevpur Colony  Maheshwaram  Malkajgiri  Mallapur  Mamidipally  Manchirevula  Manikonda  Manneguda  Mansoorabad  Medchal  Miyapur  Mokila  Moti Nagar  Nacharam  Nagole  Nagulapally  Nallagandla Gachibowli  Nallakunta  Nanakramguda  Narsingi  Nawab Saheb Kunta  Neredmet  Nizampet  Osman Nagar  Padmarao Nagar  Patancheru  Patighanpur  Peerzadiguda  Pocharam  Pragathi Nagar Kukatpally  Premavathi Pet  Puppalaguda  Qutub Shahi Tombs  Rai Durg  Rajendra Nagar  Ramachandrapuram  Saidabad  Sainikpuri  Sangareddy  Saroor Nagar  Serilingampally  Shadnagar  Shaikpet  Shamirpet  Shamshabad  Shankarpalli  Shankarpally Road  Sultanpur  Tellapur  Trimalgherry  Tukkuguda  Turkayamjal  Uppal Kalan  Vanasthalipuram  Velmala  Apartment  Independent House  Villa
# 1738           4               3         False         False  False     False     False     False                      False    False       False      False    False             False          False       False     False    False     False       False      False        False       False       False          False                    False           False     False       False       False              False       False        True         False        False      False    False       False    False      False   False                        False      False    False   False     False     False   False              False       False       False     False      False     False              False        False       False     False        False         False      False      False        False    False    False   False       False     False   False        False                   False       False         False     False              False     False     False        False           False       False        False         False     False                      False           False        False              False     False           False             False     False       False       False         False            False      False     False      False       False         False              False      False     False         False      False        False        False            False    True       False              False    13
# 1182           2               2         False         False  False     False     False     False                      False    False       False      False    False             False          False       False     False    False     False       False      False        False       False       False          False                    False           False     False       False       False              False       False        False        False        False      False    False       False    False      False   False                        False      False    False   False     False     False   False              False       False       False     False      False     False              False        False       False     False        False         False      False      False        False    False    False   False       False     False   False        False                   False       False         False     False              False     False     False        False           False       False        False         False     False                      False           False        False              False     False           False             False     False       False       False         False            False      False     False      False       True          False              False      False     False         False      False        False        False            False    True       False              False    12
# 1905           2               3         False         False  False     False     False     False                      False    False       False      False    False             False          False       False     False    False     False       False      False        False       False       False          False                    False           False     False       False       False              False       False        False        False        False      False    False       False    False      False   False                        False      True     False   False     False     False   False              False       False       False     False      False     False              False        False       False     False        False         False      False      False        False    False    False   False       False     False   False        False                   False       False         False     False              False     False     False        False           False       False        False         False     False                      False           False        False              False     False           False             False     False       False       False         False            False      False     False      False       False         False              False      False     False         False      False        False        False            False    True       False              False     9
# 3183           0               4         False         False  False     False     False     False                      False    False       False      False    False             False          False       False     False    False     False       False      False        False       False       False          False                    False           False     False       False       False              False       False        False        False        False      False    False       False    False      False   False                        False      False    False   False     False     False   False              False       False       False     False      False     False              False        False       False     False        False         False      False      False        False    False    False   False       False     False   False        False                   False       False         False     False              False     False     False        False           False       False        False         False     False                      False           False        False              False     False           True              False     False       False       False         False            False      False     False      False       False         False              False      False     False         False      False        False        False            False    False      False              True      8
# 2000          -1               3         False         False  False     False     False     False                      False    False       False      False    False             False          False       False     False    False     False       False      False        False       False       False          False                    False           False     False       False       False              False       False        False        False        False      False    False       False    False      False   False                        False      False    False   False     False     False   False              False       False       False     False      False     False              False        False       False     False        False         False      False      False        False    False    False   False       False     False   False        False                   False       False         False     False              False     False     False        False           False       False        False         False     False                      False           False        False              False     False           False             False     False       False       False         False            False      False     False      False       False         False              False      True      False         False      False        False        False            False    True       False              False     8
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ..
# 1536           1               2         False         False  False     False     False     False                      False    False       False      False    False             False          False       False     False    False     False       False      False        False       False       False          False                    False           False     False       False       False              False       False        False        False        False      False    False       False    False      False   False                        False      False    False   False     False     False   False              False       False       False     False      False     False              False        False       False     False        False         False      False      False        False    False    False   False       False     False   False        False                   False       False         False     False              False     False     False        False           False       False        False         False     False                      False           False        False              False     False           False             False     False       False       False         True             False      False     False      False       False         False              False      False     False         False      False        False        False            False    True       False              False     1
# 1538           2               3         False         False  False     False     False     False                      False    False       False      False    True              False          False       False     False    False     False       False      False        False       False       False          False                    False           False     False       False       False              False       False        False        False        False      False    False       False    False      False   False                        False      False    False   False     False     False   False              False       False       False     False      False     False              False        False       False     False        False         False      False      False        False    False    False   False       False     False   False        False                   False       False         False     False              False     False     False        False           False       False        False         False     False                      False           False        False              False     False           False             False     False       False       False         False            False      False     False      False       False         False              False      False     False         False      False        False        False            False    True       False              False     1
# 1540           1               3         False         False  False     False     False     False                      False    False       False      False    False             False          False       False     False    False     False       False      False        False       False       False          False                    False           False     False       False       False              False       False        False        False        False      False    False       False    False      False   False                        False      True     False   False     False     False   False              False       False       False     False      False     False              False        False       False     False        False         False      False      False        False    False    False   False       False     False   False        False                   False       False         False     False              False     False     False        False           False       False        False         False     False                      False           False        False              False     False           False             False     False       False       False         False            False      False     False      False       False         False              False      False     False         False      False        False        False            False    True       False              False     1
# 1543           1               3         False         False  False     False     False     False                      False    False       False      False    False             False          False       False     False    False     False       False      False        False       False       False          False                    False           False     False       False       False              False       False        False        False        False      False    False       False    False      False   False                        False      False    False   True      False     False   False              False       False       False     False      False     False              False        False       False     False        False         False      False      False        False    False    False   False       False     False   False        False                   False       False         False     False              False     False     False        False           False       False        False         False     False                      False           False        False              False     False           False             False     False       False       False         False            False      False     False      False       False         False              False      False     False         False      False        False        False            False    True       False              False     1
# 1750           2               3         False         False  False     False     False     False                      False    False       False      False    False             False          False       False     False    False     False       False      False        False       False       False          False                    False           False     False       False       False              False       False        False        False        False      False    False       False    False      False   False                        False      True     False   False     False     False   False              False       False       False     False      False     False              False        False       False     False        False         False      False      False        False    False    False   False       False     False   False        False                   False       False         False     False              False     False     False        False           False       False        False         False     False                      False           False        False              False     False           False             False     False       False       False         False            False      False     False      False       False         False              False      False     False         False      False        False        False            False    True       False              False     1
# Name: count, Length: 1235, dtype: int64

# %%
predict_cost('AS Rao Nagar','Apartment', 680, 0, 2)*10000000
# Out:
# c:\Users\rohit\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# 3782928.5714285728

# %%
predict_cost('Kompally','Apartment', 1700, 0, 3)*10000000
# Out:
# c:\Users\rohit\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# 10465000.00000001

# %%
import pickle
with open('hyderabad_home_prices_model.pickle','wb') as f:
    pickle.dump(rf_model,f)

# %%
import json
columns = {
    'data_columns' : [col.lower() for col in X.columns]
}
with open("columns.json","w") as f:
    f.write(json.dumps(columns))
